# %%
import sys
sys.path.append("../")

import re

from urllib.parse import urlparse
import pandas as pd
from mastodon import Mastodon
from datetime import datetime
from desci_sense.shared_functions.schema.post import RefPost
from desci_sense.shared_functions.dataloaders.mastodon.mastodon_loader import MastodonLoader
from desci_sense.shared_functions.dataloaders.mastodon.filter_timeline import FilterTimeline
from desci_sense.shared_functions.dataloaders.mastodon.check_publication import CheckPublication 
from desci_sense.shared_functions.web_extractors.citoid import fetch_citation

# %%
# create mastodon api token (https://sohwatt.com/generating-a-token-on-mastodon/)
# and set as environment variable using `export MASTODON_ACCESS_TOKEN="your_access_token_here"`
mloader = MastodonLoader()
ftimeline=FilterTimeline()

# %%
accts = ["@ShaRef@mastodon.social","@ronent@mastodon.social"]
posts = mloader.load_profiles(mastodon_accounts=accts)

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('/Users/shaharorielkagan/Documents/Python/desci-sense/nlp/notebooks/data/mastodon_accts_30v2.csv')

# Extract the 'accts' column and convert it to a list
accts = df['accts'].tolist()

# Now accts_list contains all values from the 'accts' column
print(accts)

posts = mloader.load_profiles(mastodon_accounts=accts)
# Out:
# ['@roopikarisam@mastodon.social', '@laurahelmuth@mastodon.social', '@nfanget@sciencemastodon.com', '@brianvastag@sciencemastodon.com', '@molly0xfff@hachyderm.io', '@ronent@mastodon.social', '@DWitte@mastodon.social', '@cjfaraday@zirk.us', '@aliceroberts@mastodonapp.uk', '@chrischirp@fediscience.org', '@erictopol@mstdn.social', '@cfiesler@hci.social', '@natematias@social.coop', '@KevinMKruse@mastodon.social', '@jeffjarvis@mastodon.social', '@jbf1755@mastodon.social', '@Andy8chi@mastodon.scot', '@DrHannahGraham@mastodon.scot', '@hobs@mstdn.social ', '@taylorlorenz@mastodon.social', '@o_garcia_ponce@mastodon.social', '@JPinaSanchez@sciences.social', '@josh@fediscience.org', '@urnov@genomic.social', '@ewanbirney@genomic.social', '@ScottishGENES@mastodon.scot', '@ScientistSoph@mastodon.online', '@jentaub@mstdn.social', '@scottjshapiro@mastodon.social', '@LeahLitman@mastodon.social']

# %%
start_date = datetime(2024, 2, 2)  
end_date = datetime(2024, 4, 2) 
posts_1 = ftimeline.filter_timeline(mastodon_accounts=accts, start_date=start_date, end_date=end_date)
posts_1
# Out:
# [{'id': 112015186027469107,
#   'content': '<p>An incredible DEFCon speaker event is coming up with Dr. Elena Foulis! Join us 3/19 at 2pm eastern for &quot;Latina/o/e Digital Humanities as Places of Joy and Querencia for Students.&quot; Register now! <a href="http://digitalethnicfutures.org/uncategorized/defcon-speaker-foulis/" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">http://</span><span class="ellipsis">digitalethnicfutures.org/uncat</span><span class="invisible">egorized/defcon-speaker-foulis/</span></a> <a href="https://mastodon.social/tags/AcademicMastodon" class="mention hashtag" rel="tag">#<span>AcademicMastodon</span></a> <a href="https://mastodon.social/tags/DigitalHumanities" class="mention hashtag" rel="tag">#<span>DigitalHumanities</span></a></p>',
#   'created_at': datetime.datetime(2024, 2, 29, 14, 14, 55, 392000, tzinfo=tzutc()),
#   'account_id': 28059,
#   'username': 'roopikarisam'},
#  {'id': 111997913527212347,
#   'content': '<p>Thanks to Sritama Chatterjee for an exceptional essay, the directors and reviewers who participated, and Stacy Reardon, one of our managing editors. <a href="https://mastodon.social/tags/ReviewsInDH" class="mention hashtag" rel="tag">#<span>ReviewsInDH</span></a></p>',
#   'created_at': datetime.datetime(2024, 2, 26, 13, 2, 17, 963000, tzinfo=tzutc()),
#   'account_id': 28059,
#   'username': 'roopikarisam'},
#  {'id': 111997908551810277,
#   'content': '<p>A review of Migration Diaries, a digital archive of migrants&#39; stories from the Northern Indian Ocean, directed by Aarthi Sridhar and Annu Jalais, and reviewed by Neelofer Qadir  <a href="https://mastodon.social/tags/ReviewsInDH" class="mention hashtag" rel="tag">#<span>ReviewsInDH</span></a> <a href="https://reviewsindh.pubpub.org/pub/migration-diaries" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://</span><span class="ellipsis">reviewsindh.pubpub.org/pub/mig</span><span class="invisible">ration-diaries</span></a></p>',
#   'created_at': datetime.datetime(2024, 2, 26, 13, 1, 2, 34000, tzinfo=tzutc()),
#   'account_id': 28059,
#   'username': 'roopikarisam'},
#  {'id': 111997900002770404,
#   'content': '<p>A review of The Global Yemen Project, a digital collection of oral poetry by Yemeni women, directed by Gokh Amin Alshaif and reviewed by Sam  Liebhaber <a href="https://mastodon.social/tags/ReviewsInDH" class="mention hashtag" rel="tag">#<span>ReviewsInDH</span></a> <a href="https://reviewsindh.pubpub.org/pub/global-yemen-project" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://</span><span class="ellipsis">reviewsindh.pubpub.org/pub/glo</span><span class="invisible">bal-yemen-project</span></a></p>',
#   'created_at': datetime.datetime(2024, 2, 26, 12, 58, 51, 586000, tzinfo=tzutc()),
#   'account_id': 28059,
#   'username': 'roopikarisam'},
#  {'id': 111997895414327627,
#   'content': '<p>*A review of Afro-Asian Networks Visualized, a data visualization project  exploring internationalism between 1945 and 1965, directed by Rachel  Leow, Su Lin Lewis, and Carolien Stolte and reviewed by Oishani Sengupta <a href="https://mastodon.social/tags/ReviewsInDH" class="mention hashtag" rel="tag">#<span>ReviewsInDH</span></a> <a href="https://reviewsindh.pubpub.org/pub/afro-asian-networks-visualized" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://</span><span class="ellipsis">reviewsindh.pubpub.org/pub/afr</span><span class="invisible">o-asian-networks-visualized</span></a></p>',
#   'created_at': datetime.datetime(2024, 2, 26, 12, 57, 41, 573000, tzinfo=tzutc()),
#   'account_id': 28059,
#   'username': 'roopikarisam'},
#  {'id': 112133769467842812,
#   'content': '<p>Kitten season is out of control. “It’s terrifying. It just keeps getting earlier and going later.” <a href="https://www.scientificamerican.com/article/kitten-season-is-out-of-control-are-warmer-winters-to-blame/" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://www.</span><span class="ellipsis">scientificamerican.com/article</span><span class="invisible">/kitten-season-is-out-of-control-are-warmer-winters-to-blame/</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 21, 12, 52, 15, 92000, tzinfo=tzutc()),
#   'account_id': 109245762060994274,
#   'username': 'laurahelmuth'},
#  {'id': 112128808173290476,
#   'content': '<p>Cool cool cool: Comet 12P/Pons-Brooks is one of the brightest comets ever detected AND it&#39;s going to peak right around the time of the total solar eclipse AND a new photo shows its core is spiraling   <a href="https://www.scientificamerican.com/article/stunning-comet-spiral-offers-glimpse-of-icy-snowball-at-its-core/" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://www.</span><span class="ellipsis">scientificamerican.com/article</span><span class="invisible">/stunning-comet-spiral-offers-glimpse-of-icy-snowball-at-its-core/</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 20, 15, 50, 31, 747000, tzinfo=tzutc()),
#   'account_id': 109245762060994274,
#   'username': 'laurahelmuth'},
#  {'id': 112128639822586389,
#   'content': '<p>Here&#39;s a gorgeous photo of a lenticular cloud lit up by a volcano  <a href="https://www.scientificamerican.com/article/lava-lit-lenticular-cloud-crowns-volcano-in-spectacular-photo/" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://www.</span><span class="ellipsis">scientificamerican.com/article</span><span class="invisible">/lava-lit-lenticular-cloud-crowns-volcano-in-spectacular-photo/</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 20, 15, 7, 42, 919000, tzinfo=tzutc()),
#   'account_id': 109245762060994274,
#   'username': 'laurahelmuth'},
#  {'id': 112124290495496015,
#   'content': '<p>Snakes grow quickly, can fast for months without losing much muscle, and as ectotherms don&#39;t need to use energy to stay warm. They could be an efficient &amp; climate-friendly source of farmed protein <a href="https://www.scientificamerican.com/article/snake-steak-could-be-a-climate-friendly-source-of-protein" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://www.</span><span class="ellipsis">scientificamerican.com/article</span><span class="invisible">/snake-steak-could-be-a-climate-friendly-source-of-protein</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 19, 20, 41, 37, 454000, tzinfo=tzutc()),
#   'account_id': 109245762060994274,
#   'username': 'laurahelmuth'},
#  {'id': 112122682552784382,
#   'content': '<p>&quot;Do you really need yet another COVID-19 shot?</p><p>As a geriatrician who exclusively cares for people over 65 years of age, this is a question I’ve been asked many times over the past few years.</p><p>In early 2024, the short answer is yes.&quot; <br /> <a href="https://www.scientificamerican.com/article/why-people-aged-65-and-older-should-get-a-spring-covid-vaccine/" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://www.</span><span class="ellipsis">scientificamerican.com/article</span><span class="invisible">/why-people-aged-65-and-older-should-get-a-spring-covid-vaccine/</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 19, 13, 52, 42, 196000, tzinfo=tzutc()),
#   'account_id': 109245762060994274,
#   'username': 'laurahelmuth'},
#  {'id': 112132291404780773,
#   'content': '<p>New article! Read Metabolic profiles outperform the microbiota in assessing the response of vaginal microenvironments to the changed state of HPV infection <a href="https://www.nature.com/articles/s41522-024-00500-0?utm_source=dlvr.it&amp;utm_medium=mastodon" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">nature.com/articles/s41522-024</span><span class="invisible">-00500-0?utm_source=dlvr.it&amp;utm_medium=mastodon</span></a> in npj Biofilms</p>',
#   'created_at': datetime.datetime(2024, 3, 21, 6, 36, 19, tzinfo=tzutc()),
#   'account_id': 109308491313350363,
#   'username': 'nfanget'},
#  {'id': 112132291069648157,
#   'content': '<p>New article! Read Lactobacillus rhamnosus GG ameliorates hyperuricemia in a novel model <a href="https://www.nature.com/articles/s41522-024-00486-9?utm_source=dlvr.it&amp;utm_medium=mastodon" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">nature.com/articles/s41522-024</span><span class="invisible">-00486-9?utm_source=dlvr.it&amp;utm_medium=mastodon</span></a> in npj Biofilms</p>',
#   'created_at': datetime.datetime(2024, 3, 21, 6, 36, 14, tzinfo=tzutc()),
#   'account_id': 109308491313350363,
#   'username': 'nfanget'},
#  {'id': 112126707744577164,
#   'content': '<p>New article! Read Ginseng extracts improve circadian clock gene expression and reduce inflammation directly and indirectly through gut microbiota and PI3K signaling pathway <a href="https://www.nature.com/articles/s41522-024-00498-5?utm_source=dlvr.it&amp;utm_medium=mastodon" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">nature.com/articles/s41522-024</span><span class="invisible">-00498-5?utm_source=dlvr.it&amp;utm_medium=mastodon</span></a> in npj Biofilms</p>',
#   'created_at': datetime.datetime(2024, 3, 20, 6, 56, 20, tzinfo=tzutc()),
#   'account_id': 109308491313350363,
#   'username': 'nfanget'},
#  {'id': 112126707421398511,
#   'content': '<p>New article! Read Competition quenching strategies reduce antibiotic tolerance in polymicrobial biofilms <a href="https://www.nature.com/articles/s41522-024-00489-6?utm_source=dlvr.it&amp;utm_medium=mastodon" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">nature.com/articles/s41522-024</span><span class="invisible">-00489-6?utm_source=dlvr.it&amp;utm_medium=mastodon</span></a> in npj Biofilms</p>',
#   'created_at': datetime.datetime(2024, 3, 20, 6, 56, 15, tzinfo=tzutc()),
#   'account_id': 109308491313350363,
#   'username': 'nfanget'},
#  {'id': 112123181956505248,
#   'content': '<p>New article! Read Switch of innate to adaptative immune responses in the brain of patients with Alzheimer’s disease correlates with tauopathy progression <a href="https://www.nature.com/articles/s41514-024-00145-5?utm_source=dlvr.it&amp;utm_medium=mastodon" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">nature.com/articles/s41514-024</span><span class="invisible">-00145-5?utm_source=dlvr.it&amp;utm_medium=mastodon</span></a> in npj Aging</p>',
#   'created_at': datetime.datetime(2024, 3, 19, 15, 59, 40, tzinfo=tzutc()),
#   'account_id': 109308491313350363,
#   'username': 'nfanget'},
#  {'id': 112131184284226024,
#   'content': '<p>Anyone who thinks Julian Assange is anything other than a megalomaniac completely divorced from reality should read this:</p><p><a href="https://www.lrb.co.uk/the-paper/v36/n05/andrew-o-hagan/ghosting" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">lrb.co.uk/the-paper/v36/n05/an</span><span class="invisible">drew-o-hagan/ghosting</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 21, 1, 54, 45, tzinfo=tzutc()),
#   'account_id': 109327362715368962,
#   'username': 'brianvastag'},
#  {'id': 112131033226816905,
#   'content': '<p>More coconuts around here than we can drink, send help.</p>',
#   'created_at': datetime.datetime(2024, 3, 21, 1, 16, 21, tzinfo=tzutc()),
#   'account_id': 109327362715368962,
#   'username': 'brianvastag'},
#  {'id': 112131030493296608,
#   'content': '<p>Just put a coconut from the dwarf Samoan coconut tree into the bucket of water and held it down. </p><p>WHAT WILL HAPPEN????</p><p><a href="https://sciencemastodon.com/tags/nuts" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>nuts</span></a> <a href="https://sciencemastodon.com/tags/trees" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>trees</span></a> <a href="https://sciencemastodon.com/tags/coconuts" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>coconuts</span></a> <a href="https://sciencemastodon.com/tags/Hawaii" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Hawaii</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 21, 1, 15, 37, tzinfo=tzutc()),
#   'account_id': 109327362715368962,
#   'username': 'brianvastag'},
#  {'id': 112130069426980300,
#   'content': '<p>*cuboids if you want to be a pedantic nerd</p>',
#   'created_at': datetime.datetime(2024, 3, 20, 21, 11, 15, tzinfo=tzutc()),
#   'account_id': 109327362715368962,
#   'username': 'brianvastag'},
#  {'id': 112130062112536825,
#   'content': '<p>Where the cubes go, nobody knows.</p>',
#   'created_at': datetime.datetime(2024, 3, 20, 21, 9, 22, tzinfo=tzutc()),
#   'account_id': 109327362715368962,
#   'username': 'brianvastag'},
#  {'id': 112130398934362168,
#   'content': "<p>He was probably about fifteen, although it's guesswork with adult strays. Give your pets a big hug today.</p>",
#   'created_at': datetime.datetime(2024, 3, 20, 22, 34, 32, tzinfo=tzutc()),
#   'account_id': 109332160649392039,
#   'username': 'molly0xfff'},
#  {'id': 112130396827904773,
#   'content': "<p>He was the greatest older brother to Ruthie (even though she scared him at first) and he raised her ever since she joined us at only a few weeks old. I think it's wonderful that she grew up to look like his mini-me.</p>",
#   'created_at': datetime.datetime(2024, 3, 20, 22, 34, 15, tzinfo=tzutc()),
#   'account_id': 109332160649392039,
#   'username': 'molly0xfff'},
#  {'id': 112130347463335029,
#   'content': '<p>He had an incredibly hard first half to his life, during which he was abandoned and endured some horrific things. He was eventually rescued by a feral cat rescue organization in Boston, and then he came to me for foster. Despite all he went through, he loved everyone he met.</p>',
#   'created_at': datetime.datetime(2024, 3, 20, 22, 21, 49, tzinfo=tzutc()),
#   'account_id': 109332160649392039,
#   'username': 'molly0xfff'},
#  {'id': 112130344071047300,
#   'content': "<p>I had to say goodbye to my Max this week after an unexpected and rapid decline. I'm heartbroken, but more than anything, I'm so grateful for the 6½ years we got to spend together. He was my first pet, and he taught me so much. He never, ever stopped purring. I miss him terribly.</p>",
#   'created_at': datetime.datetime(2024, 3, 20, 22, 20, 53, tzinfo=tzutc()),
#   'account_id': 109332160649392039,
#   'username': 'molly0xfff'},
#  {'id': 112112605928434228,
#   'content': '<p>mom i\'m scared can you come pick me up? the all in guys are tweeting about crypto again</p><p><a href="https://hachyderm.io/tags/crypto" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>crypto</span></a> <a href="https://hachyderm.io/tags/cryptocurrency" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>cryptocurrency</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 17, 19, 9, 53, tzinfo=tzutc()),
#   'account_id': 109332160649392039,
#   'username': 'molly0xfff'},
#  {'id': 112133650709373730,
#   'content': '<p><span class="h-card" translate="no"><a href="https://mastodon.social/@tkuhn" class="u-url mention">@<span>tkuhn</span></a></span> <span class="h-card" translate="no"><a href="https://mas.to/@nanopub" class="u-url mention">@<span>nanopub</span></a></span> <br />Recording is available at:<br /><a href="https://archive.org/details/kuhn-metagov-20240320" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://</span><span class="ellipsis">archive.org/details/kuhn-metag</span><span class="invisible">ov-20240320</span></a><br />Thanks again Tobias for the excellent talk!</p>',
#   'created_at': datetime.datetime(2024, 3, 21, 12, 22, 2, 987000, tzinfo=tzutc()),
#   'account_id': 107714271376772838,
#   'username': 'ronent'},
#  {'id': 112128804495947228,
#   'content': '<p>Join us today at 12:00 p.m ET (in 10 minutes!) for the Metagov seminar where <span class="h-card" translate="no"><a href="https://mastodon.social/@tkuhn" class="u-url mention">@<span>tkuhn</span></a></span> will give a talk on the Nanopublications project <span class="h-card" translate="no"><a href="https://mas.to/@nanopub" class="u-url mention">@<span>nanopub</span></a></span> <a href="https://researchseminars.org/talk/Metagov/183/" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://</span><span class="ellipsis">researchseminars.org/talk/Meta</span><span class="invisible">gov/183/</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 20, 15, 49, 35, 636000, tzinfo=tzutc()),
#   'account_id': 107714271376772838,
#   'username': 'ronent'},
#  {'id': 112119235586169086,
#   'content': '<p>AI was revolutionized by an old idea (neural nets) revisited with new tools (massive compute/data)<br />Similarly, CI (collective intelligence) will be revolutionized by an old idea (semantic web) revisited with new tools (AI + decentralized tech)<br />What makes the CI revolution harder is that it is a sociotechnical revolution and not just a technical one - it will require collective participation and cultural changes, not an elite that will &quot;solve&quot; everything for us</p>',
#   'created_at': datetime.datetime(2024, 3, 18, 23, 16, 5, 935000, tzinfo=tzutc()),
#   'account_id': 107714271376772838,
#   'username': 'ronent'},
#  {'id': 112133270344631246,
#   'content': '<p>New! Prof Steve Griffin taking us back to pandemic basics: viruses, immunity, mitigations and the future!</p><p>have a read of the latest Indie SAGE substack!</p><p><a href="https://open.substack.com/pub/independentsage/p/when-will-the-covid-race-be-run?r=315tdh&amp;utm_campaign=post&amp;utm_medium=web&amp;showWelcomeOnShare=true" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">open.substack.com/pub/independ</span><span class="invisible">entsage/p/when-will-the-covid-race-be-run?r=315tdh&amp;utm_campaign=post&amp;utm_medium=web&amp;showWelcomeOnShare=true</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 21, 10, 45, 15, tzinfo=tzutc()),
#   'account_id': 109302105064359670,
#   'username': 'chrischirp'},
#  {'id': 112129363443175263,
#   'content': '<p>Hello! Our live briefings may have stopped, but we haven\'t! </p><p>Indie SAGE has started a (free) Substack - subscribe now to get regular info about all aspects of the pandemic from Indie SAGE members :-) </p><p><a href="https://open.substack.com/pub/independentsage/p/independent-sage-has-joined-substack?r=315tdh&amp;utm_campaign=post&amp;utm_medium=web&amp;showWelcomeOnShare=true" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">open.substack.com/pub/independ</span><span class="invisible">entsage/p/independent-sage-has-joined-substack?r=315tdh&amp;utm_campaign=post&amp;utm_medium=web&amp;showWelcomeOnShare=true</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 20, 18, 11, 40, tzinfo=tzutc()),
#   'account_id': 109302105064359670,
#   'username': 'chrischirp'},
#  {'id': 112096449182709197,
#   'content': '<p>Great Covid update from Bob Hawkins. </p><p>TLDR: All Covid measures are low and either stable or falling. </p><p>Infection survey also has estimate of current chance of hospitalisation on infection by age </p><p><a href="https://bhawkins3.substack.com/p/covid-situation-report-mar-14-2024?utm_source=substack&amp;publication_id=2056298&amp;post_id=142611549&amp;utm_medium=email&amp;utm_content=share&amp;utm_campaign=email-share&amp;triggerShare=true&amp;isFreemail=true&amp;r=1qm7of&amp;triedRedirect=true" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">bhawkins3.substack.com/p/covid</span><span class="invisible">-situation-report-mar-14-2024?utm_source=substack&amp;publication_id=2056298&amp;post_id=142611549&amp;utm_medium=email&amp;utm_content=share&amp;utm_campaign=email-share&amp;triggerShare=true&amp;isFreemail=true&amp;r=1qm7of&amp;triedRedirect=true</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 14, 22, 41, 12, tzinfo=tzutc()),
#   'account_id': 109302105064359670,
#   'username': 'chrischirp'},
#  {'id': 112061453397950208,
#   'content': '<p>Another International Women\'s Day post - this time on why girls avoid Physics A-Level - and it isn\'t cos the maths is too hard.</p><p><a href="https://open.substack.com/pub/christinapagel/p/girls-do-not-avoid-physics-cos-the?r=8zv6v&amp;utm_campaign=post&amp;utm_medium=web&amp;showWelcomeOnShare=true" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">open.substack.com/pub/christin</span><span class="invisible">apagel/p/girls-do-not-avoid-physics-cos-the?r=8zv6v&amp;utm_campaign=post&amp;utm_medium=web&amp;showWelcomeOnShare=true</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 8, 18, 21, 15, tzinfo=tzutc()),
#   'account_id': 109302105064359670,
#   'username': 'chrischirp'},
#  {'id': 112061342026647045,
#   'content': '<p>A post for International Women\'s Day</p><p>"Being embarrassed about periods, taboos for women talking about them, men not wanting to know, has all stopped us researching &amp; treating it. It\'s wasting women\'s potential. Too little has changed in 50 YEARS. This has to stop"</p><p><a href="https://open.substack.com/pub/christinapagel/p/periods-we-need-to-stop-ignoring?r=8zv6v&amp;utm_campaign=post&amp;utm_medium=web&amp;showWelcomeOnShare=true" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">open.substack.com/pub/christin</span><span class="invisible">apagel/p/periods-we-need-to-stop-ignoring?r=8zv6v&amp;utm_campaign=post&amp;utm_medium=web&amp;showWelcomeOnShare=true</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 8, 17, 52, 55, tzinfo=tzutc()),
#   'account_id': 109302105064359670,
#   'username': 'chrischirp'},
#  {'id': 112091358940326519,
#   'content': '<p>Four years ago today, 13 March, the US declared Covid a national emergency. We\'re still learning about <a href="https://mstdn.social/tags/SARSCoV2" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>SARSCoV2</span></a> every day, and here\'s a recap of important stuff in the past week. In the new Ground Truths. Subscriptions are free.</p><p><a href="https://erictopol.substack.com/p/covid-4-years-on" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">erictopol.substack.com/p/covid</span><span class="invisible">-4-years-on</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 14, 1, 6, 37, tzinfo=tzutc()),
#   'account_id': 109287481946236477,
#   'username': 'erictopol'},
#  {'id': 112085299735054920,
#   'content': '<p>Covid vaccination markedly reduced blood clots, heart attacks, heart failure, stroke and other adverse cardiovascular outcomes, as seen from over 20 million people, about half of whom were vaccinated <a href="https://heart.bmj.com/content/early/2024/01/24/heartjnl-2023-323483" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">heart.bmj.com/content/early/20</span><span class="invisible">24/01/24/heartjnl-2023-323483</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 12, 23, 25, 41, tzinfo=tzutc()),
#   'account_id': 109287481946236477,
#   'username': 'erictopol'},
#  {'id': 112084679743520205,
#   'content': '<p>Beyond ~30 million excess deaths, "The COVID-19 pandemic caused the most severe drops in life expectancy seen in 50+ years."<br><a href="https://healthdata.org/research-analysis/library/mortality-life-expectancy-and-population" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">healthdata.org/research-analys</span><span class="invisible">is/library/mortality-life-expectancy-and-population</span></a> <br> <br><a href="https://thelancet.com/journals/lancet/article/PIIS0140-6736(24)00476-8/fulltext" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">thelancet.com/journals/lancet/</span><span class="invisible">article/PIIS0140-6736(24)00476-8/fulltext</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 12, 20, 48, tzinfo=tzutc()),
#   'account_id': 109287481946236477,
#   'username': 'erictopol'},
#  {'id': 112083201810291260,
#   'content': '<p>An update on protection of Covid vaccination against death and the political partisan gap on US Death tolls (←curves are still diverging)</p>',
#   'created_at': datetime.datetime(2024, 3, 12, 14, 32, 8, tzinfo=tzutc()),
#   'account_id': 109287481946236477,
#   'username': 'erictopol'},
#  {'id': 112077803054605353,
#   'content': '<p>An enthralling conversation with Daphne Koller on the convergence of A.I. and life science </p><p><a href="https://erictopol.substack.com/p/daphne-koller-the-convergence-of" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">erictopol.substack.com/p/daphn</span><span class="invisible">e-koller-the-convergence-of</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 11, 15, 39, 9, tzinfo=tzutc()),
#   'account_id': 109287481946236477,
#   'username': 'erictopol'},
#  {'id': 112130683752210353,
#   'content': '<p>It’s the day before the conference (<a href="https://hci.social/tags/SIGCSE2024" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>SIGCSE2024</span></a>) and I’ve already run into one student who enthusiastically thanked me for my YouTube videos. 🥰</p>',
#   'created_at': datetime.datetime(2024, 3, 20, 23, 47, 16, tzinfo=tzutc()),
#   'account_id': 109248541965183859,
#   'username': 'cfiesler'},
#  {'id': 112118406165790628,
#   'content': '<p>A huge congratulations to <span class="h-card" translate="no"><a href="https://hci.social/@shamikalashawn" class="u-url mention" rel="nofollow noopener noreferrer" target="_blank">@<span>shamikalashawn</span></a></span> for successfully defending her dissertation today! So proud to be her advisor. ♥️</p>',
#   'created_at': datetime.datetime(2024, 3, 18, 19, 44, 51, tzinfo=tzutc()),
#   'account_id': 109248541965183859,
#   'username': 'cfiesler'},
#  {'id': 112099405689076472,
#   'content': '<p>I know that I shouldn’t be surprised by this at all but now that Threads has picked up some steam, it’s full of a bunch of the same flavor of terrible people I used to have to block on Twitter! Block block block block block.</p>',
#   'created_at': datetime.datetime(2024, 3, 15, 11, 12, 40, tzinfo=tzutc()),
#   'account_id': 109248541965183859,
#   'username': 'cfiesler'},
#  {'id': 112095493476731004,
#   'content': '<p>FYI:  I\'ve talked to several journalists over the past couple of days about TikTok (e.g. here\'s a video, enjoy my dinosaur sweater <a href="https://www.reuters.com/world/us/us-house-vote-tiktok-crackdown-fate-uncertain-senate-2024-03-12/" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">reuters.com/world/us/us-house-</span><span class="invisible">vote-tiktok-crackdown-fate-uncertain-senate-2024-03-12/</span></a>) and would be very happy to talk to more.</p>',
#   'created_at': datetime.datetime(2024, 3, 14, 18, 37, 56, tzinfo=tzutc()),
#   'account_id': 109248541965183859,
#   'username': 'cfiesler'},
#  {'id': 112078165248546129,
#   'content': '<p>I suppose it\'s time to re-share this op-ed I wrote about <a href="https://hci.social/tags/TikTok" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>TikTok</span></a> again. Also happy to speak with journalists on this topic. I have a lot of feelings. :) <a href="https://slate.com/technology/2023/03/tiktok-hearing-what-congress-missed.html" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">slate.com/technology/2023/03/t</span><span class="invisible">iktok-hearing-what-congress-missed.html</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 11, 17, 10, 48, tzinfo=tzutc()),
#   'account_id': 109248541965183859,
#   'username': 'cfiesler'},
#  {'id': 112123660898772487,
#   'content': '<p>🎵 "What I want to know... is how does it know... that I like Rhinos?" 🎵</p><p>🎵 "Why does it think that this is what I want to see?" 🎵</p><p>Amazing PBS Kids music video about search &amp; recommender algorithms.</p><p><a href="https://www.youtube.com/watch?v=x-Bp6YeSDMA&amp;t=885s" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">youtube.com/watch?v=x-Bp6YeSDM</span><span class="invisible">A&amp;t=885s</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 19, 18, 0, 28, tzinfo=tzutc()),
#   'account_id': 109401928088768223,
#   'username': 'natematias'},
#  {'id': 112116941794059530,
#   'content': "<p>I've heard a few folks say I might fall behind if I don't integrate LLMs into my work processes. </p><p>I've been looking for an analogy. People said the same thing about microwork services for document prep, research, etc. Looking back, I don't think I lost anything by doing my own thinking and paying professionals reasonable rates when I needed help. I may even have saved a bit of time in task definition and quality control.</p>",
#   'created_at': datetime.datetime(2024, 3, 18, 13, 32, tzinfo=tzutc()),
#   'account_id': 109401928088768223,
#   'username': 'natematias'},
#  {'id': 112113261904783241,
#   'content': '<p>New post: This winter, I was floored by a beautifully-elegant prayer about supply chains by the 19th century minister Maltbie Babcock.</p><p>In this post for my Christian peers/audience, I write about what it means to integrate an understanding of infrastructure into our worship</p><p><a href="https://social.coop/tags/christianity" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>christianity</span></a> <a href="https://social.coop/tags/prayer" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>prayer</span></a> <a href="https://social.coop/tags/infrastructure" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>infrastructure</span></a> <a href="https://social.coop/tags/cycling" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>cycling</span></a> <a href="https://social.coop/tags/food" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>food</span></a></p><p><a href="https://natematias.medium.com/singing-a-prayer-for-supply-chains-1de09c8e0496" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">natematias.medium.com/singing-</span><span class="invisible">a-prayer-for-supply-chains-1de09c8e0496</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 17, 21, 56, 50, tzinfo=tzutc()),
#   'account_id': 109401928088768223,
#   'username': 'natematias'},
#  {'id': 112086494668294873,
#   'content': '<p>"if you’re visionaries, why are you all doing the same thing at the same time, all the time?"</p><p>interview by <span class="h-card" translate="no"><a href="https://mastodon.social/@taylorlorenz" class="u-url mention" rel="nofollow noopener noreferrer" target="_blank">@<span>taylorlorenz</span></a></span> <br><a href="https://www.washingtonpost.com/entertainment/movies/2024/03/12/disruptors-adam-frucci-silicon-valley/" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">washingtonpost.com/entertainme</span><span class="invisible">nt/movies/2024/03/12/disruptors-adam-frucci-silicon-valley/</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 13, 4, 29, 38, tzinfo=tzutc()),
#   'account_id': 109401928088768223,
#   'username': 'natematias'},
#  {'id': 112073905195817670,
#   'content': '<p>As I participate in standard-setting on AI safety, I\'m aware that standards ultimately determine *who* gets to have a voice in tech policy. This has been clear in the history of air quality, where debates over standards are actually about whether affected communities have a voice when polluters make their families and their environment sick.</p><p>This article by Gwen Ottinger tells the story of the Louisiana Bucket Brigade and the role of standards in their work.</p><p><a href="https://journals.sagepub.com/doi/abs/10.1177/0162243909337121?casa_token=SHEvsEArxa4AAAAA:2rU1fbYDh1kfUg_YrTpjtBnEK7DcymGxOoc0WHmqdYYn8VR6ASj4mNfxYTkHnu6bz0pNV8cO02waTw" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">journals.sagepub.com/doi/abs/1</span><span class="invisible">0.1177/0162243909337121?casa_token=SHEvsEArxa4AAAAA:2rU1fbYDh1kfUg_YrTpjtBnEK7DcymGxOoc0WHmqdYYn8VR6ASj4mNfxYTkHnu6bz0pNV8cO02waTw</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 10, 23, 7, 55, tzinfo=tzutc()),
#   'account_id': 109401928088768223,
#   'username': 'natematias'},
#  {'id': 112133453714536708,
#   'content': '<p>US reportedly considering plea deal offer for Julian Assange<br /><a href="https://www.theguardian.com/media/2024/mar/20/julian-assange-wikileaks-plea-deal" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://www.</span><span class="ellipsis">theguardian.com/media/2024/mar</span><span class="invisible">/20/julian-assange-wikileaks-plea-deal</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 21, 11, 31, 57, 81000, tzinfo=tzutc()),
#   'account_id': 109243139631965273,
#   'username': 'jeffjarvis'},
#  {'id': 112133438427597389,
#   'content': '<p>California narrowly passes Prop 1 plan aimed at tackling homelessness crisis<br /><a href="https://www.theguardian.com/us-news/2024/mar/20/california-prop-1-passes-homelessness-mental-health-system" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://www.</span><span class="ellipsis">theguardian.com/us-news/2024/m</span><span class="invisible">ar/20/california-prop-1-passes-homelessness-mental-health-system</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 21, 11, 28, 3, 820000, tzinfo=tzutc()),
#   'account_id': 109243139631965273,
#   'username': 'jeffjarvis'},
#  {'id': 112133404947940650,
#   'content': '<p>Good by <span class="h-card" translate="no"><a href="https://twitter.dev.holtwick.de/users/kevinroose" class="u-url mention">@<span>kevinroose</span></a></span> (gift link):<br />Reddit’s I.P.O. Is a Content Moderation Success Story <a href="https://www.nytimes.com/2024/03/21/technology/reddit-ipo-public-content-moderation.html?unlocked_article_code=1.eU0.1L9u.fopauO4TeQxO&amp;smid=tw-share" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://www.</span><span class="ellipsis">nytimes.com/2024/03/21/technol</span><span class="invisible">ogy/reddit-ipo-public-content-moderation.html?unlocked_article_code=1.eU0.1L9u.fopauO4TeQxO&amp;smid=tw-share</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 21, 11, 19, 32, 964000, tzinfo=tzutc()),
#   'account_id': 109243139631965273,
#   'username': 'jeffjarvis'},
#  {'id': 112133345656357111,
#   'content': '<p>Pamela Paul&#39;s column is what people thought really bad blogs were (but weren&#39;t; it&#39;s worse)...<br />Adding Insult to Injury <a href="https://www.nytimes.com/2024/03/21/opinion/injury-human-aging.html?pvid=6THtN_AmjoLhpwGwhb46p-cM&amp;ugrp=c&amp;smid=tw-share" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://www.</span><span class="ellipsis">nytimes.com/2024/03/21/opinion</span><span class="invisible">/injury-human-aging.html?pvid=6THtN_AmjoLhpwGwhb46p-cM&amp;ugrp=c&amp;smid=tw-share</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 21, 11, 4, 28, 247000, tzinfo=tzutc()),
#   'account_id': 109243139631965273,
#   'username': 'jeffjarvis'},
#  {'id': 112133227929235830,
#   'content': '<p>Translation: &quot;Bad candidates&quot; is the Washington Post&#39;s term for fascist, authoritarian, racist, white nationalist, nutballs cultists...<br />Could Republicans blow it with bad candidates — again? <a href="https://www.washingtonpost.com/politics/2024/03/20/ohio-senate-moreno-trump-senate-republicans/" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://www.</span><span class="ellipsis">washingtonpost.com/politics/20</span><span class="invisible">24/03/20/ohio-senate-moreno-trump-senate-republicans/</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 21, 10, 34, 31, 871000, tzinfo=tzutc()),
#   'account_id': 109243139631965273,
#   'username': 'jeffjarvis'},
#  {'id': 112096365057008272,
#   'content': '<p>Tomorrow on “History Matters:” </p><p>Some REAL Talk About Higher Education.</p><p>It’s remarkable how many people pontificating about college education have never been in a classroom.</p><p>I have 26 years worth.<br />Join us for some truths.</p><p>Friday 10AM ET<br />NCHEteach.org/conversations</p><p><a href="https://mastodon.social/tags/history" class="mention hashtag" rel="tag">#<span>history</span></a> <a href="https://mastodon.social/tags/politics" class="mention hashtag" rel="tag">#<span>politics</span></a> <a href="https://mastodon.social/tags/education" class="mention hashtag" rel="tag">#<span>education</span></a> <a href="https://mastodon.social/tags/democracy" class="mention hashtag" rel="tag">#<span>democracy</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 14, 22, 19, 49, 81000, tzinfo=tzutc()),
#   'account_id': 109243371263223446,
#   'username': 'jbf1755'},
#  {'id': 112058058832885878,
#   'content': '<p>One last point.</p><p>The Republican responding to the address is speaking from her kitchen and talking about her children and God, and wearing a cross.</p><p>Keep your eyes open.</p><p><a href="https://mastodon.social/tags/SOTU" class="mention hashtag" rel="tag">#<span>SOTU</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 8, 3, 58, 2, 489000, tzinfo=tzutc()),
#   'account_id': 109243371263223446,
#   'username': 'jbf1755'},
#  {'id': 112058047017793170,
#   'content': '<p>OK.<br />I posted the <a href="https://mastodon.social/tags/SOTU" class="mention hashtag" rel="tag">#<span>SOTU</span></a> on every frickin&#39; social media platform while sipping a martini.</p><p>I&#39;m going to bed.</p><p>Want to hear what this speech suggests in the context of history?</p><p>Join me tomorrow morning at 10AM ET on my webcast, History Matters.</p><p>NCHEteach.org/conversations</p><p><a href="https://mastodon.social/tags/SOTU" class="mention hashtag" rel="tag">#<span>SOTU</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 8, 3, 55, 2, 206000, tzinfo=tzutc()),
#   'account_id': 109243371263223446,
#   'username': 'jbf1755'},
#  {'id': 112058037351797108,
#   'content': '<p>This is a man who&#39;s ready to fight.</p><p><a href="https://mastodon.social/tags/SOTU" class="mention hashtag" rel="tag">#<span>SOTU</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 8, 3, 52, 34, 710000, tzinfo=tzutc()),
#   'account_id': 109243371263223446,
#   'username': 'jbf1755'},
#  {'id': 112058019060291884,
#   'content': '<p>Somehow, this was a state of the Union address AND a campaign speech.<br />He was aggressive.<br />He presented a vision.<br />He was passionate.<br />He went for over an hour.<br />He dealt with hecklers.<br />He&#39;s ready to fight.</p><p>SHUT UP about the doddering old guy rhetoric.<br />PLEASE.<br />For crying out loud.</p><p><a href="https://mastodon.social/tags/SOTU" class="mention hashtag" rel="tag">#<span>SOTU</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 8, 3, 47, 55, 603000, tzinfo=tzutc()),
#   'account_id': 109243371263223446,
#   'username': 'jbf1755'},
#  {'id': 112116294334151245,
#   'content': '<p>Edinburgh survey on Police Leadership (Please complete and boost). </p><p><a href="https://edinburghinformatics.eu.qualtrics.com/jfe/form/SV_9LhzQI2slXFtYEK" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">edinburghinformatics.eu.qualtr</span><span class="invisible">ics.com/jfe/form/SV_9LhzQI2slXFtYEK</span></a></p><p>MSc Criminology student Grace Bell is looking for Edinburgh residents to complete a 15 minute survey on police leadership for a degree project. </p><p>Please help by completing at the link above!</p><p><a href="https://mastodon.scot/tags/Edinburgh" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Edinburgh</span></a> <a href="https://mastodon.scot/tags/Leith" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Leith</span></a> <a href="https://mastodon.scot/tags/Granton" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Granton</span></a> <a href="https://mastodon.scot/tags/Gorgie" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Gorgie</span></a> <a href="https://mastodon.scot/tags/Dalry" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Dalry</span></a> <a href="https://mastodon.scot/tags/Sighthill" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Sighthill</span></a> <a href="https://mastodon.scot/tags/Corstorphine" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Corstorphine</span></a> <a href="https://mastodon.scot/tags/Liberton" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Liberton</span></a> <a href="https://mastodon.scot/tags/Craigmillar" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Craigmillar</span></a> <a href="https://mastodon.scot/tags/Muirhouse" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Muirhouse</span></a> <a href="https://mastodon.scot/tags/Silverknowes" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Silverknowes</span></a> <a href="https://mastodon.scot/tags/Cramond" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Cramond</span></a> <a href="https://mastodon.scot/tags/Sighthill" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Sighthill</span></a> <a href="https://mastodon.scot/tags/Colinton" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Colinton</span></a> <a href="https://mastodon.scot/tags/Slateford" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Slateford</span></a> <a href="https://mastodon.scot/tags/Oxgangs" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Oxgangs</span></a> <a href="https://mastodon.scot/tags/Marchmont" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Marchmont</span></a> <a href="https://mastodon.scot/tags/Blackford" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Blackford</span></a> <a href="https://mastodon.scot/tags/Morningside" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Morningside</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 18, 10, 48, 4, tzinfo=tzutc()),
#   'account_id': 109382054615909828,
#   'username': 'Andy8chi'},
#  {'id': 112095528859267987,
#   'content': '<p>So Armenia submit a band called Ladaniva to <a href="https://mastodon.scot/tags/Eurovision" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Eurovision</span></a>, and now I have no choice but to vote for them. It\'s the rules.</p><p><a href="https://mastodon.scot/tags/Lada" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Lada</span></a> <a href="https://mastodon.scot/tags/Niva" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Niva</span></a> <a href="https://mastodon.scot/tags/LadaNiva" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>LadaNiva</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 14, 18, 47, 8, tzinfo=tzutc()),
#   'account_id': 109382054615909828,
#   'username': 'Andy8chi'},
#  {'id': 112077910021009279,
#   'content': '<p>New paper! <a href="https://mastodon.scot/tags/OpenAccess" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>OpenAccess</span></a> </p><p>Victims, Perpetrators and Bystanders: Atrocity and Its Aftermath in the Films of Jasmila Žbanić</p><p>In this paper, I explore 4 of Žbanić\'s films and argue that she represents a strong example of a critical victimology in cinematic form.</p><p><a href="https://academic.oup.com/bjc/advance-article/doi/10.1093/bjc/azae014/7625412" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">academic.oup.com/bjc/advance-a</span><span class="invisible">rticle/doi/10.1093/bjc/azae014/7625412</span></a></p><p><a href="https://mastodon.scot/tags/Film" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Film</span></a> <a href="https://mastodon.scot/tags/Cinema" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Cinema</span></a> <a href="https://mastodon.scot/tags/Criminology" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Criminology</span></a> <a href="https://mastodon.scot/tags/Bosnia" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Bosnia</span></a> <a href="https://mastodon.scot/tags/BosniaAndHerzegovina" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>BosniaAndHerzegovina</span></a> <a href="https://mastodon.scot/tags/Atrocity" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Atrocity</span></a> <a href="https://mastodon.scot/tags/Genocide" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Genocide</span></a> <a href="https://mastodon.scot/tags/WarCrimes" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>WarCrimes</span></a> <a href="https://mastodon.scot/tags/Law" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Law</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 11, 16, 6, 25, tzinfo=tzutc()),
#   'account_id': 109382054615909828,
#   'username': 'Andy8chi'},
#  {'id': 112064705859663810,
# ...
#   'created_at': datetime.datetime(2024, 3, 13, 19, 3, 18, tzinfo=tzutc()),
#   'account_id': 109240651750188703,
#   'username': 'josh'},
#  {'id': 112050072624366754,
#   'content': '<p>Cool <a href="https://fediscience.org/tags/citizenscience" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>citizenscience</span></a> project <a href="https://fediscience.org/tags/heritage" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>heritage</span></a> <a href="https://fediscience.org/tags/dh" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>dh</span></a> <a href="https://fediscience.org/tags/archives" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>archives</span></a> <a href="https://www.archives.gov/citizen-archivist/missions/revolutionary-war-pension-files" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">archives.gov/citizen-archivist</span><span class="invisible">/missions/revolutionary-war-pension-files</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 6, 18, 7, 1, tzinfo=tzutc()),
#   'account_id': 109240651750188703,
#   'username': 'josh'},
#  {'id': 112050071110579115,
#   'content': '<p>"Indiana University joins forces with RDA-US to advance Open Science Standards"</p><p><a href="https://news.iu.edu/live/news/33921-indiana-university-joins-forces-with-rda-us-to-advance" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://</span><span class="ellipsis">news.iu.edu/live/news/33921-in</span><span class="invisible">diana-university-joins-forces-with-rda-us-to-advance</span></a></p><p><a href="https://fediscience.org/tags/hoosiermast" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>hoosiermast</span></a> <a href="https://fediscience.org/tags/opendata" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>opendata</span></a> <a href="https://fediscience.org/tags/openscience" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>openscience</span></a> <a href="https://fediscience.org/tags/IndianaUniversity" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>IndianaUniversity</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 6, 18, 6, 36, tzinfo=tzutc()),
#   'account_id': 109240651750188703,
#   'username': 'josh'},
#  {'id': 112109986326881620,
#   'content': '<p>Happy St. Patrick\'s Day! My Irish themed genealogy books are available in the UK from <a href="https://www.pen-and-sword.co.uk/Chris-Paton/a/1799" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">pen-and-sword.co.uk/Chris-Pato</span><span class="invisible">n/a/1799</span></a><br>at £10.49 (offer) +p&amp;p, and from the USA at <a href="https://www.penandswordbooks.com/search-grid/?keyword=Paton" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">penandswordbooks.com/search-gr</span><span class="invisible">id/?keyword=Paton</span></a> - I hope they help! <a href="https://mastodon.scot/tags/Ireland" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Ireland</span></a> <a href="https://mastodon.scot/tags/NorthernIreland" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>NorthernIreland</span></a> <a href="https://mastodon.scot/tags/genealogy" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>genealogy</span></a> <a href="https://mastodon.scot/tags/FamilyHistory" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>FamilyHistory</span></a> <a href="https://mastodon.scot/tags/stpatricksday" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>stpatricksday</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 17, 8, 3, 53, tzinfo=tzutc()),
#   'account_id': 109296790418919597,
#   'username': 'ScottishGENES'},
#  {'id': 112107123945157338,
#   'content': '<p>Great visiting Aberdeen and North-East Scotland FHS today, the first time I\'ve given a presentation in- person since January 2020. Wonderful reception - 185 attendees (45 at the venue, rest via Zoom), and great feedback after - thanks Aberdeen! 🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007f👍😃 <a href="https://mastodon.scot/tags/genealogy" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>genealogy</span></a> <a href="https://mastodon.scot/tags/FamilyHistory" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>FamilyHistory</span></a> <a href="https://mastodon.scot/tags/Scotland" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Scotland</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 16, 19, 55, 56, tzinfo=tzutc()),
#   'account_id': 109296790418919597,
#   'username': 'ScottishGENES'},
#  {'id': 112105071022829963,
#   'content': '<p>I\'m raising money for the An Lòchran Scottish Gaelic arts and cultural centre in Partick by doing the Kiltwalk between Glasgow and Loch Lomond on April 28th, and am overwhelmed at the support given to me so far - mòran taing! My final stretch target is £1500 - if you have an interest in Gaelic and would like to donate, it would be appreciated! My JustGiving page is at <a href="https://www.justgiving.com/page/chris-paton-stewarton" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">justgiving.com/page/chris-pato</span><span class="invisible">n-stewarton</span></a> - for more on An Lòchran please visit <a href="https://www.anlochran.com" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="">anlochran.com</span><span class="invisible"></span></a> <br><a href="https://mastodon.scot/tags/Gaelic" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Gaelic</span></a> <a href="https://mastodon.scot/tags/G%C3%A0idhlig" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Gàidhlig</span></a> <a href="https://mastodon.scot/tags/Scotland" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Scotland</span></a> <a href="https://mastodon.scot/tags/Alba" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Alba</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 16, 11, 13, 51, tzinfo=tzutc()),
#   'account_id': 109296790418919597,
#   'username': 'ScottishGENES'},
#  {'id': 112088929691256488,
#   'content': '<p>The Scotland 1750-1850: Beyond the Old Parish Registers course starts on April 8th, and runs for 5 weeks, taught by me, Chris Paton! For furtehr details please visit <a href="https://www.pharostutors.com/scotland-1750-1850-beyond-the-old-parish-registers" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">https://www.</span><span class="ellipsis">pharostutors.com/scotland-1750</span><span class="invisible">-1850-beyond-the-old-parish-registers</span></a> - it would be great to see you there!   <a href="https://mastodon.scot/tags/Scotland" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Scotland</span></a> <span class="h-card" translate="no"><a href="https://genealysis.social/@PharosTutors" class="u-url mention" rel="nofollow noopener noreferrer" target="_blank">@<span>PharosTutors</span></a></span> <a href="https://mastodon.scot/tags/genealogy" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>genealogy</span></a> <a href="https://mastodon.scot/tags/FamilyHistory" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>FamilyHistory</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 13, 14, 48, 54, tzinfo=tzutc()),
#   'account_id': 109296790418919597,
#   'username': 'ScottishGENES'},
#  {'id': 112087577519249976,
#   'content': '<p>Scottish Jewish Archives Open Day  <a href="http://scottishgenes.blogspot.com/2024/03/scottish-jewish-archives-open-day.html" rel="nofollow noopener noreferrer" translate="no" target="_blank"><span class="invisible">http://</span><span class="ellipsis">scottishgenes.blogspot.com/202</span><span class="invisible">4/03/scottish-jewish-archives-open-day.html</span></a> <a href="https://mastodon.scot/tags/Scotland" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>Scotland</span></a> <a href="https://mastodon.scot/tags/genealogy" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>genealogy</span></a> <a href="https://mastodon.scot/tags/FamilyHistory" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>FamilyHistory</span></a> <a href="https://mastodon.scot/tags/archives" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>archives</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 13, 9, 5, 1, tzinfo=tzutc()),
#   'account_id': 109296790418919597,
#   'username': 'ScottishGENES'},
#  {'id': 112088253794596340,
#   'content': '<p>Today\'s <a href="https://mastodon.online/tags/OccupationOfTheDay" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>OccupationOfTheDay</span></a> is…GARMENT INSPECTOR:</p><p>"examines and supervises work during process and on completion; returns defective work for correction; often books out work to operatives and does other clerical work, e.g. control of wages sheets; in some trades, may also finish garments"</p><p>Dict of Occup\'l Terms (1927)<br>📷 Garment factory, c.1935-1942 c/o NYPL <a href="https://mastodon.online/tags/history" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>history</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 13, 11, 56, 58, tzinfo=tzutc()),
#   'account_id': 109295941342143160,
#   'username': 'ScientistSoph'},
#  {'id': 112077515599179856,
#   'content': '<p>Today\'s <a href="https://mastodon.online/tags/OccupationOfTheDay" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>OccupationOfTheDay</span></a> is…BARNMAN:</p><p>An agricultural worker who threshed the crop; alternative name for a "thresher".</p><p>Dict. Scots Lang. (2005)<br>📷 Barnmen or threshers, Indiana (1936) c/o NYPL <a href="https://mastodon.online/tags/history" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>history</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 11, 14, 26, 8, tzinfo=tzutc()),
#   'account_id': 109295941342143160,
#   'username': 'ScientistSoph'},
#  {'id': 112059474399066041,
#   'content': '<p>Today\'s <a href="https://mastodon.online/tags/OccupationOfTheDay" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>OccupationOfTheDay</span></a> is…JENNY-MUCK:</p><p>Scots term for a working woman, in particular a female farm worker.</p><p>Scottish National Dictionary (1960)<br>📷 Scots advert for the Women\'s Land Army, c.1940 c/o Wikimedia Commons <a href="https://mastodon.online/tags/history" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>history</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 8, 9, 58, tzinfo=tzutc()),
#   'account_id': 109295941342143160,
#   'username': 'ScientistSoph'},
#  {'id': 112019927331540596,
#   'content': '<p>Today\'s <a href="https://mastodon.online/tags/OccupationOfTheDay" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>OccupationOfTheDay</span></a> is…KLONDYKER:</p><p>Worker engaged in "exporting fresh herring packed in salt and ice by fast steamer; (in 20thC) to export fresh fish, mainly mackerel, to the Continent, direct to factory ships for processing on board."</p><p>Dict. Scots Lang. (2005)<br>📷 Mackerel fishing (1943) c/o Library of Congress <a href="https://mastodon.online/tags/history" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>history</span></a></p>',
#   'created_at': datetime.datetime(2024, 3, 1, 10, 20, 40, tzinfo=tzutc()),
#   'account_id': 109295941342143160,
#   'username': 'ScientistSoph'},
#  {'id': 111997325944909931,
#   'content': '<p>Today\'s <a href="https://mastodon.online/tags/OccupationOfTheDay" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>OccupationOfTheDay</span></a> is…JACKER-UP (lead pencil making):</p><p>"places a number of glued pencils together in a clamp, and screws down clamp to make glueing secure; removes pencils when clamping is complete."</p><p>Dict Occup\'l Terms (1927)<br>📷 Faber pencil factory, 1917-18 c/o Flickr <a href="https://mastodon.online/tags/history" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>history</span></a></p>',
#   'created_at': datetime.datetime(2024, 2, 26, 10, 32, 50, tzinfo=tzutc()),
#   'account_id': 109295941342143160,
#   'username': 'ScientistSoph'},
#  {'id': 112060860182541249,
#   'content': '<p>The only Alabamians not making fun of Katie Britt are in vats of liquid nitrogen.</p>',
#   'created_at': datetime.datetime(2024, 3, 8, 15, 50, 27, 688000, tzinfo=tzutc()),
#   'account_id': 109243342914018772,
#   'username': 'scottjshapiro'},
#  {'id': 111992155177248604,
#   'content': '<p>Did a very deep dive into the numbers</p>',
#   'created_at': datetime.datetime(2024, 2, 25, 12, 37, 52, 507000, tzinfo=tzutc()),
#   'account_id': 109243342914018772,
#   'username': 'scottjshapiro'},
#  {'id': 111980659035780316,
#   'content': '',
#   'created_at': datetime.datetime(2024, 2, 23, 11, 54, 15, 312000, tzinfo=tzutc()),
#   'account_id': 109243342914018772,
#   'username': 'scottjshapiro'},
#  {'id': 111975037911607511,
#   'content': '<p>The originalist case for infertility</p>',
#   'created_at': datetime.datetime(2024, 2, 22, 12, 4, 43, 759000, tzinfo=tzutc()),
#   'account_id': 109243342914018772,
#   'username': 'scottjshapiro'},
#  {'id': 111918706720824806,
#   'content': '<p>Being so old, the <span class="h-card" translate="no"><a href="https://mastodon.social/@nytimes" class="u-url mention">@<span>nytimes</span></a></span> forgot how it screwed up the 2016 presidential campaign</p>',
#   'created_at': datetime.datetime(2024, 2, 12, 13, 18, 58, 4000, tzinfo=tzutc()),
#   'account_id': 109243342914018772,
#   'username': 'scottjshapiro'}]

# %%
df = pd.DataFrame(posts_1)


# Define a regular expression pattern for URLs
url_pattern = r'https?://[^\s<>"]+|www\.[^\s<>"]+'

# Function to extract URLs from a given text
def extract_urls(text):
    url_pattern = r'https?://[^\s<>"]+|www\.[^\s<>"]+'
    return re.findall(url_pattern, text)

# Apply the function to the 'content' column of your DataFrame
df['urls'] = df['content'].apply(extract_urls)

# Now 'urls' column will contain lists of extracted URLs
df[['content', 'urls']]
# Out:
#                                               content  \
# 0   <p>An incredible DEFCon speaker event is comin...
# 1   <p>Thanks to Sritama Chatterjee for an excepti...
# 2   <p>A review of Migration Diaries, a digital ar...
# 3   <p>A review of The Global Yemen Project, a dig...
# 4   <p>*A review of Afro-Asian Networks Visualized...
# ..                                                ...
# 89  <p>The only Alabamians not making fun of Katie...
# 90       <p>Did a very deep dive into the numbers</p>
# 91
# 92        <p>The originalist case for infertility</p>
# 93  <p>Being so old, the <span class="h-card" tran...
#
#                                                  urls
# 0   [http://digitalethnicfutures.org/uncategorized...
# 1          [https://mastodon.social/tags/ReviewsInDH]
# 2   [https://mastodon.social/tags/ReviewsInDH, htt...
# 3   [https://mastodon.social/tags/ReviewsInDH, htt...
# 4   [https://mastodon.social/tags/ReviewsInDH, htt...
# ..                                                ...
# 89                                                 []
# 90                                                 []
# 91                                                 []
# 92                                                 []
# 93                 [https://mastodon.social/@nytimes]
#
# [94 rows x 2 columns]

# %%
import sys
sys.path.append("../")
from desci_sense.shared_functions.web_extractors.citoid import fetch_citation

target_url = " https://paragraph.xyz/@sense-nets/pt3-prototyping"

fetch_citation(target_url)
# Out:
# {'key': 'BGRW6UFK',
#  'version': 0,
#  'itemType': 'webpage',
#  'creators': [],
#  'tags': [],
#  'title': 'Sensemaking Networks Part 3: building partnerships and prototypes',
#  'url': 'https://paragraph.xyz/@sense-nets/pt3-prototyping',
#  'abstractNote': 'Semantic cross-posters for re-integrating science social media',
#  'date': '2024-03-11',
#  'language': 'en',
#  'accessDate': '2024-03-21',
#  'shortTitle': 'Sensemaking Networks Part 3',
#  'websiteTitle': 'paragraph.xyz',
#  'original_url': ' https://paragraph.xyz/@sense-nets/pt3-prototyping'}

# %%
def check_publication(row):
    # Assume the row['urls'] is a list of URLs
    for url in row['urls']:
        if fetch_citation(url):
            return 1
    return 0
df['publication'] = df.apply(check_publication, axis=1)
df
# Out:
#                     id                                            content  \
# 0   112015186027469107  <p>An incredible DEFCon speaker event is comin...
# 1   111997913527212347  <p>Thanks to Sritama Chatterjee for an excepti...
# 2   111997908551810277  <p>A review of Migration Diaries, a digital ar...
# 3   111997900002770404  <p>A review of The Global Yemen Project, a dig...
# 4   111997895414327627  <p>*A review of Afro-Asian Networks Visualized...
# ..                 ...                                                ...
# 89  112060860182541249  <p>The only Alabamians not making fun of Katie...
# 90  111992155177248604       <p>Did a very deep dive into the numbers</p>
# 91  111980659035780316
# 92  111975037911607511        <p>The originalist case for infertility</p>
# 93  111918706720824806  <p>Being so old, the <span class="h-card" tran...
#
#                          created_at          account_id       username  \
# 0  2024-02-29 14:14:55.392000+00:00               28059   roopikarisam
# 1  2024-02-26 13:02:17.963000+00:00               28059   roopikarisam
# 2  2024-02-26 13:01:02.034000+00:00               28059   roopikarisam
# 3  2024-02-26 12:58:51.586000+00:00               28059   roopikarisam
# 4  2024-02-26 12:57:41.573000+00:00               28059   roopikarisam
# ..                              ...                 ...            ...
# 89 2024-03-08 15:50:27.688000+00:00  109243342914018772  scottjshapiro
# 90 2024-02-25 12:37:52.507000+00:00  109243342914018772  scottjshapiro
# 91 2024-02-23 11:54:15.312000+00:00  109243342914018772  scottjshapiro
# 92 2024-02-22 12:04:43.759000+00:00  109243342914018772  scottjshapiro
# 93 2024-02-12 13:18:58.004000+00:00  109243342914018772  scottjshapiro
#
#                                                  urls  publication
# 0   [http://digitalethnicfutures.org/uncategorized...            1
# 1          [https://mastodon.social/tags/ReviewsInDH]            1
# 2   [https://mastodon.social/tags/ReviewsInDH, htt...            1
# 3   [https://mastodon.social/tags/ReviewsInDH, htt...            1
# 4   [https://mastodon.social/tags/ReviewsInDH, htt...            1
# ..                                                ...          ...
# 89                                                 []            0
# 90                                                 []            0
# 91                                                 []            0
# 92                                                 []            0
# 93                 [https://mastodon.social/@nytimes]            1
#
# [94 rows x 7 columns]

# %%
import pandas as pd
from urllib.parse import quote
import requests

# Assuming the fetch_citation function is defined as before and it returns None if the citation is not found

def check_publication_and_store_metadata(row):
    metadata_columns = {}
    # Iterate over each URL in the 'urls' list within the row
    for i, url in enumerate(row['urls']):
        citation = fetch_citation(url)
        # Check if the citation is valid (not an error message)
        if citation and 'DOI' in citation:
            # Store the metadata in a dictionary with a dynamic key based on the URL index
            metadata_columns[f'url_{i+1}_meta_info'] = citation
        else:
            # If no valid citation was found, use None or an empty dict, based on your preference
            metadata_columns[f'url_{i+1}_meta_info'] = None
    
    # If no valid citations were found at all, set 'publication' to 0
    if not any(metadata_columns.values()):
        row['publication'] = 0
    else:
        # If at least one valid citation was found, set 'publication' to 1
        row['publication'] = 1
        # Update the row with the metadata columns
        row.update(metadata_columns)
    
    return row



# Apply the function to each row
df = df.apply(check_publication_and_store_metadata, axis=1)

# Display the DataFrame
print(df)
# Out:
#                     id                                            content  \
# 0   112015186027469107  <p>An incredible DEFCon speaker event is comin...
# 1   111997913527212347  <p>Thanks to Sritama Chatterjee for an excepti...
# 2   111997908551810277  <p>A review of Migration Diaries, a digital ar...
# 3   111997900002770404  <p>A review of The Global Yemen Project, a dig...
# 4   111997895414327627  <p>*A review of Afro-Asian Networks Visualized...
# ..                 ...                                                ...
# 89  112060860182541249  <p>The only Alabamians not making fun of Katie...
# 90  111992155177248604       <p>Did a very deep dive into the numbers</p>
# 91  111980659035780316
# 92  111975037911607511        <p>The originalist case for infertility</p>
# 93  111918706720824806  <p>Being so old, the <span class="h-card" tran...
#
#                          created_at          account_id       username  \
# 0  2024-02-29 14:14:55.392000+00:00               28059   roopikarisam
# 1  2024-02-26 13:02:17.963000+00:00               28059   roopikarisam
# 2  2024-02-26 13:01:02.034000+00:00               28059   roopikarisam
# 3  2024-02-26 12:58:51.586000+00:00               28059   roopikarisam
# 4  2024-02-26 12:57:41.573000+00:00               28059   roopikarisam
# ..                              ...                 ...            ...
# 89 2024-03-08 15:50:27.688000+00:00  109243342914018772  scottjshapiro
# 90 2024-02-25 12:37:52.507000+00:00  109243342914018772  scottjshapiro
# 91 2024-02-23 11:54:15.312000+00:00  109243342914018772  scottjshapiro
# 92 2024-02-22 12:04:43.759000+00:00  109243342914018772  scottjshapiro
# 93 2024-02-12 13:18:58.004000+00:00  109243342914018772  scottjshapiro
#
#                                                  urls  publication
# 0   [http://digitalethnicfutures.org/uncategorized...            0
# 1          [https://mastodon.social/tags/ReviewsInDH]            0
# 2   [https://mastodon.social/tags/ReviewsInDH, htt...            1
# 3   [https://mastodon.social/tags/ReviewsInDH, htt...            1
# 4   [https://mastodon.social/tags/ReviewsInDH, htt...            1
# ..                                                ...          ...
# 89                                                 []            0
# 90                                                 []            0
# 91                                                 []            0
# 92                                                 []            0
# 93                 [https://mastodon.social/@nytimes]            0
#
# [94 rows x 7 columns]

# %%
print(df['content'][0])
# Out:
# <p>My dear partner just published an important paper on barriers to the integration of Somali Muslim urban refugee girls in Uganda. <br /><a href="https://www.berghahnjournals.com/view/journals/girlhood-studies/17/1/ghs170108.xml" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://www.</span><span class="ellipsis">berghahnjournals.com/view/jour</span><span class="invisible">nals/girlhood-studies/17/1/ghs170108.xml</span></a></p>

# %%
from bs4 import BeautifulSoup


# Mastodon posts are return in HTML format, we want to present them in a clean format.
# Function to extract and clean text from HTML
def extract_and_clean_text(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    return soup.get_text()

# Apply the function to each row in the content column
df['Text'] = df['content'].apply(extract_and_clean_text)

print(df['Text'])
# Out:
# 0     An incredible DEFCon speaker event is coming u...
# 1     Thanks to Sritama Chatterjee for an exceptiona...
# 2     A review of Migration Diaries, a digital archi...
# 3     A review of The Global Yemen Project, a digita...
# 4     *A review of Afro-Asian Networks Visualized, a...
#                             ...
# 89    The only Alabamians not making fun of Katie Br...
# 90                Did a very deep dive into the numbers
# 91
# 92                 The originalist case for infertility
# 93    Being so old, the @nytimes forgot how it screw...
# Name: Text, Length: 94, dtype: object

# %% [markdown]
# ### Labeling the dataset

# %%
#If publication field is 1 we a True Label as academic.
df['True Label'] = ''

for i in df[df['publication'] == 1].index:
    
    df['True Label'][i] = 'academic'

print(df["True Label"])
# Out:
# 0
# 1
# 2     academic
# 3     academic
# 4     academic
#         ...
# 89
# 90
# 91
# 92
# 93
# Name: True Label, Length: 94, dtype: object
# /var/folders/j3/1_zy_b4s2517g8j_rjjdhd4h0000gn/T/ipykernel_51308/2374652634.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['True Label'][i] = 'academic'

# %%
# We iterate through rows with publication value 0 and assign True Label them manually 
from IPython.display import clear_output
import time  # Import the time module



for i in df[df['publication'] == 0].index:
    print(f"Toot number {i}: {df['Text'][i]}")
    print("-----------------------")
    # Flush the output to ensure the print statements are rendered
    sys.stdout.flush()
    time.sleep(0.5)  # Pause for a short time (e.g., 0.5 seconds)
    l = 2
    while l not in [0, 1]:
        try:
            l = int(input("Insert label (0 or 1): "))
            sys.stdout.flush()
            time.sleep(0.5)  # Pause for a short time (e.g., 0.5 seconds)
        except:
            print("Bad input, try again")
            sys.stdout.flush()
            time.sleep(0.5)  # Pause for a short time (e.g., 0.5 seconds)
        
    if l == 0:      
        df['True Label'][i] = 'not-academic'
        clear_output(wait=True)
    else:
        df['True Label'][i] = 'academic'

print(df)
# Out:
#                     id                                            content  \
# 0   112015186027469107  <p>An incredible DEFCon speaker event is comin...
# 1   111997913527212347  <p>Thanks to Sritama Chatterjee for an excepti...
# 2   111997908551810277  <p>A review of Migration Diaries, a digital ar...
# 3   111997900002770404  <p>A review of The Global Yemen Project, a dig...
# 4   111997895414327627  <p>*A review of Afro-Asian Networks Visualized...
# ..                 ...                                                ...
# 89  112060860182541249  <p>The only Alabamians not making fun of Katie...
# 90  111992155177248604       <p>Did a very deep dive into the numbers</p>
# 91  111980659035780316
# 92  111975037911607511        <p>The originalist case for infertility</p>
# 93  111918706720824806  <p>Being so old, the <span class="h-card" tran...
#
#                          created_at          account_id       username  \
# 0  2024-02-29 14:14:55.392000+00:00               28059   roopikarisam
# 1  2024-02-26 13:02:17.963000+00:00               28059   roopikarisam
# 2  2024-02-26 13:01:02.034000+00:00               28059   roopikarisam
# 3  2024-02-26 12:58:51.586000+00:00               28059   roopikarisam
# 4  2024-02-26 12:57:41.573000+00:00               28059   roopikarisam
# ..                              ...                 ...            ...
# 89 2024-03-08 15:50:27.688000+00:00  109243342914018772  scottjshapiro
# 90 2024-02-25 12:37:52.507000+00:00  109243342914018772  scottjshapiro
# 91 2024-02-23 11:54:15.312000+00:00  109243342914018772  scottjshapiro
# 92 2024-02-22 12:04:43.759000+00:00  109243342914018772  scottjshapiro
# 93 2024-02-12 13:18:58.004000+00:00  109243342914018772  scottjshapiro
#
#                                                  urls  publication  \
# 0   [http://digitalethnicfutures.org/uncategorized...            0
# 1          [https://mastodon.social/tags/ReviewsInDH]            0
# 2   [https://mastodon.social/tags/ReviewsInDH, htt...            1
# 3   [https://mastodon.social/tags/ReviewsInDH, htt...            1
# 4   [https://mastodon.social/tags/ReviewsInDH, htt...            1
# ..                                                ...          ...
# 89                                                 []            0
# 90                                                 []            0
# 91                                                 []            0
# 92                                                 []            0
# 93                 [https://mastodon.social/@nytimes]            0
#
#                                                  Text    True Label
# 0   An incredible DEFCon speaker event is coming u...      academic
# 1   Thanks to Sritama Chatterjee for an exceptiona...      academic
# 2   A review of Migration Diaries, a digital archi...      academic
# 3   A review of The Global Yemen Project, a digita...      academic
# 4   *A review of Afro-Asian Networks Visualized, a...      academic
# ..                                                ...           ...
# 89  The only Alabamians not making fun of Katie Br...  not-academic
# 90              Did a very deep dive into the numbers  not-academic
# 91                                                     not-academic
# 92               The originalist case for infertility  not-academic
# 93  Being so old, the @nytimes forgot how it screw...  not-academic
#
# [94 rows x 9 columns]

# %%
import wandb
wandb.login()
# Out:
# wandb: Currently logged in as: shahar-r-oriel (common-sense-makers). Use `wandb login --relogin` to force relogin
# True

# %%
wandb.init(project="evaluation")
artifact = wandb.Artifact("toot_sci__labeling", type="dataset")

# Create a wandb.Table from the Pandas DataFrame
table = wandb.Table(dataframe=df)

# Add the wandb.Table to the artifact
artifact.add(table, "labeled_data_table")

# Log the artifact
wandb.log_artifact(artifact, aliases=["latest"])

wandb.run.finish()
# Out:
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/Users/shaharorielkagan/sensemakers/nlp/notebooks/wandb/run-20240321_165551-6a63hqgq</code>
# Syncing run <strong><a href='https://wandb.ai/common-sense-makers/evaluation/runs/6a63hqgq' target="_blank">charmed-sea-2</a></strong> to <a href='https://wandb.ai/common-sense-makers/evaluation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/common-sense-makers/evaluation' target="_blank">https://wandb.ai/common-sense-makers/evaluation</a>
#  View run at <a href='https://wandb.ai/common-sense-makers/evaluation/runs/6a63hqgq' target="_blank">https://wandb.ai/common-sense-makers/evaluation/runs/6a63hqgq</a>
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# VBox(children=(Label(value='0.110 MB of 0.110 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#  View run <strong style="color:#cdcd00">charmed-sea-2</strong> at: <a href='https://wandb.ai/common-sense-makers/evaluation/runs/6a63hqgq' target="_blank">https://wandb.ai/common-sense-makers/evaluation/runs/6a63hqgq</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240321_165551-6a63hqgq/logs</code>

# %%
# Specify the filename or path to save the CSV file
filename = '/Users/shaharorielkagan/Documents/Python/desci-sense/nlp/notebooks/data/toots_to_filter.csv'

# Write the DataFrame to a CSV file
df.to_csv(filename, index=False)

# %%
import pandas as pd
import requests
from urllib.parse import quote

def store_citation_metadata(urls):
    # Initialize an empty list to hold the metadata
    metadata_list = []

    # Loop over each URL and fetch its citation metadata
    for url in urls:
        metadata = fetch_citation(url)
        if metadata and 'DOI' in metadata:  # Check for valid metadata with a 'DOI'
            metadata_list.append(metadata)

    return metadata_list
### define the useful metadata infomation

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 32],
    'City': ['New York', 'Paris', 'Berlin', 'London']
}
df1 = pd.DataFrame(data)


# Add a column of zeros with the name "Predicted Labels"
df1['Predicted Labels'] = ''

#print(df1[df1['Name'] == 'John'].index)
# Display the updated DataFrame
print(df1)
# Out:
#     Name  Age      City Predicted Labels
# 0   John   28  New York
# 1   Anna   34     Paris
# 2  Peter   29    Berlin
# 3  Linda   32    London
